# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.style
from sklearn.linear_model import LinearRegression
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.0 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\HP\AppData\Roaming\Python\Python311\site-packages\traitlets\config\application.py", line 1043, in launch_instance
#     app.start()
# ...

# %%
df=pd.read_csv(r"C:\Users\HP\Downloads\AirBNB.csv")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9856\2611840448.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(r"C:\Users\HP\Downloads\AirBNB.csv")

# %%
df.head()
# Out:
#          id        room_type  accommodates  bathrooms cancellation_policy  \
# 0   6901257  Entire home/apt           3.0        1.0              strict
# 1   6304928  Entire home/apt           7.0        1.0              strict
# 2   7919400  Entire home/apt           5.0        1.0            moderate
# 3  13418779  Entire home/apt           4.0        1.0            flexible
# 4   3808709  Entire home/apt           2.0        1.0            moderate
#
#   cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0         True                f                 100.0       1.0   1.0
# 1         True                t                  93.0       3.0   3.0
# 2         True                t                  92.0       1.0   3.0
# 3         True                f                   NaN       2.0   2.0
# 4         True                t                  40.0       0.0   1.0
#
#    log_price
# 0   5.010635
# 1   5.129899
# 2   4.976734
# 3   6.620073
# 4   4.744932

# %%
df['cancellation_policy'].unique()
# Out:
# array(['strict', 'moderate', 'flexible', nan], dtype=object)

# %% [markdown]
# # First we will do the EDA

# %%
# we drop the id column here bcz id column will not play any role by increasing or decreasing the id will not play any role for log_price
df.drop('id',inplace=True,axis=1)

# %%
df
# Out:
#              room_type  accommodates  bathrooms cancellation_policy  \
# 0      Entire home/apt           3.0        1.0              strict
# 1      Entire home/apt           7.0        1.0              strict
# 2      Entire home/apt           5.0        1.0            moderate
# 3      Entire home/apt           4.0        1.0            flexible
# 4      Entire home/apt           2.0        1.0            moderate
# ...                ...           ...        ...                 ...
# 74106     Private room           1.0        1.0            flexible
# 74107  Entire home/apt           4.0        2.0            moderate
# 74108  Entire home/apt           5.0        1.0            moderate
# 74109  Entire home/apt           2.0        1.0              strict
# 74110  Entire home/apt           4.0        1.0            moderate
#
#       cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0             True                f                 100.0       1.0   1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   room_type             74106 non-null  object
#  1   accommodates          74108 non-null  float64
#  2   bathrooms             73908 non-null  float64
#  3   cancellation_policy   74103 non-null  object
#  4   cleaning_fee          74107 non-null  object
#  5   instant_bookable      74111 non-null  object
#  6   review_scores_rating  57389 non-null  float64
#  7   bedrooms              74019 non-null  float64
#  8   beds                  73980 non-null  float64
#  9   log_price             74111 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 5.7+ MB

# %%
df
# Out:
#              room_type  accommodates  bathrooms cancellation_policy  \
# 0      Entire home/apt           3.0        1.0              strict
# 1      Entire home/apt           7.0        1.0              strict
# 2      Entire home/apt           5.0        1.0            moderate
# 3      Entire home/apt           4.0        1.0            flexible
# 4      Entire home/apt           2.0        1.0            moderate
# ...                ...           ...        ...                 ...
# 74106     Private room           1.0        1.0            flexible
# 74107  Entire home/apt           4.0        2.0            moderate
# 74108  Entire home/apt           5.0        1.0            moderate
# 74109  Entire home/apt           2.0        1.0              strict
# 74110  Entire home/apt           4.0        1.0            moderate
#
#       cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0             True                f                 100.0       1.0   1.0
# ...

# %% [markdown]
# ### here we can see there are 74111 rows so it means in instant_bookable and in log_price there are no nan values in other columns there are nan values

# %%
cat=[]
num=[]
for i in df.columns:
    if df[i].dtype !='object':
        num.append(i)
    else:
        cat.append(i)

# %%
num
# Out:
# ['accommodates',
#  'bathrooms',
#  'review_scores_rating',
#  'bedrooms',
#  'beds',
#  'log_price']

# %%
cat
# Out:
# ['room_type', 'cancellation_policy', 'cleaning_fee', 'instant_bookable']

# %%
Data_summary=round(df[num].describe().T,2)

# %% [markdown]
# #### Now we have standard deviation and mean now we find the covariance (cov) = std/mean to find the despersion of data

# %%
Data_summary['Cov'] = Data_summary['std']*100/Data_summary['mean']

# %%
Data_summary
# Out:
#                         count   mean   std   min    25%    50%     75%    max  \
# accommodates          74108.0   3.16  2.15   1.0   2.00   2.00    4.00   16.0
# bathrooms             73908.0   1.24  0.58   0.0   1.00   1.00    1.00    8.0
# review_scores_rating  57389.0  94.07  7.84  20.0  92.00  96.00  100.00  100.0
# bedrooms              74019.0   1.27  0.85   0.0   1.00   1.00    1.00   10.0
# beds                  73980.0   1.71  1.25   0.0   1.00   1.00    2.00   18.0
# log_price             74111.0   4.78  0.72   0.0   4.32   4.71    5.22    7.6
#
#                             Cov
# accommodates          68.037975
# bathrooms             46.774194
# review_scores_rating   8.334219
# bedrooms              66.929134
# beds                  73.099415
# log_price             15.062762

# %% [markdown]
# #### here we see in the data summary that review_scores_rating and log_price is not despersed a lot from mean

# %% [markdown]
# ### Find median to mean

# %%
Data_summary['med-to-mean'] = round(Data_summary['50%']/Data_summary['mean'],2)

# %%
Data_summary
# Out:
#                         count   mean   std   min    25%    50%     75%    max  \
# accommodates          74108.0   3.16  2.15   1.0   2.00   2.00    4.00   16.0
# bathrooms             73908.0   1.24  0.58   0.0   1.00   1.00    1.00    8.0
# review_scores_rating  57389.0  94.07  7.84  20.0  92.00  96.00  100.00  100.0
# bedrooms              74019.0   1.27  0.85   0.0   1.00   1.00    1.00   10.0
# beds                  73980.0   1.71  1.25   0.0   1.00   1.00    2.00   18.0
# log_price             74111.0   4.78  0.72   0.0   4.32   4.71    5.22    7.6
#
#                             Cov  med-to-mean
# accommodates          68.037975         0.63
# bathrooms             46.774194         0.81
# review_scores_rating   8.334219         1.02
# bedrooms              66.929134         0.79
# beds                  73.099415         0.58
# log_price             15.062762         0.99

# %% [markdown]
# #### in the review_scores_rating the median to mean value is 1.02 it is normally distributed

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %%
for i in num:
    ax=sns.boxplot(data=df,x=i)
    ax.set(title='{}'.format(i),xlabel=i)
    plt.show()

# %%
for i in cat:
    print(df[i].value_counts())
    print()
# Out:
# room_type
# Entire home/apt    41308
# Private room       30635
# Shared room         2163
# Name: count, dtype: int64
#
# cancellation_policy
# strict      32500
# flexible    22543
# moderate    19060
# Name: count, dtype: int64
#
# cleaning_fee
# True     54399
# False    19708
# Name: count, dtype: int64
#
# instant_bookable
# f    54660
# t    19451
# Name: count, dtype: int64

# %%
for i in cat:
    print(df[i].value_counts(normalize=True))
    print()
# when we pass normalize=True so it will give in percentage e.g in shared room it will give 0.029so it means 3% of data is the shared room
# Out:
# room_type
# Entire home/apt    0.557418
# Private room       0.413394
# Shared room        0.029188
# Name: proportion, dtype: float64
#
# cancellation_policy
# strict      0.438579
# flexible    0.304212
# moderate    0.257210
# Name: proportion, dtype: float64
#
# cleaning_fee
# True     0.73406
# False    0.26594
# Name: proportion, dtype: float64
#
# instant_bookable
# f    0.737542
# t    0.262458
# Name: proportion, dtype: float64

# %%
# here we dont treat the outliers bcz we do not remove if the bathroom or bedroom is 16 so if we treat the outliers so
# it will remove that or place it to the Q3 so it will not be meaningful so here we dont treat the outliers

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
sns.pairplot(df,hue='log_price')

# %%
plt.figure(figsize=(15,10))
mask=np.triu(np.ones_like(df[num].corr(),dtype=bool))
sns.heatmap(round(df[num].corr(),3),annot=True,mask=mask)
# Out:
# <Axes: >

# %%
df[num].corr()
# Out:
#                       accommodates  bathrooms  review_scores_rating  bedrooms  \
# accommodates              1.000000   0.505645             -0.017093  0.709275
# bathrooms                 0.505645   1.000000              0.010527  0.589935
# review_scores_rating     -0.017093   0.010527              1.000000  0.011134
# bedrooms                  0.709275   0.589935              0.011134  1.000000
# beds                      0.810798   0.525598             -0.027330  0.709415
# log_price                 0.567580   0.355425              0.091219  0.473214
#
#                           beds  log_price
# accommodates          0.810798   0.567580
# bathrooms             0.525598   0.355425
# review_scores_rating -0.027330   0.091219
# bedrooms              0.709415   0.473214
# beds                  1.000000   0.442153
# log_price             0.442153   1.000000

# %%
# here we see that accomodates and beds are highly correlated and beds and bedrooms are highly correlated so which one we choose
#so here in the accomodates and beds we see that accomodates is highly correlated with the log_price so we take accomodates and
#from beds and bedrooms bedrooms is highly correlated with log_price so we take bedrooms here.

# %% [markdown]
# # CONVERT CAT VARIABLES INTO INTEGER

# %%
cat
# Out:
# ['room_type', 'cancellation_policy', 'cleaning_fee', 'instant_bookable']

# %%
df['cleaning_fee'] = df['cleaning_fee'].replace({"True": 1, "False": 0})

# %%
df
# Out:
#              room_type  accommodates  bathrooms cancellation_policy  \
# 0      Entire home/apt           3.0        1.0              strict
# 1      Entire home/apt           7.0        1.0              strict
# 2      Entire home/apt           5.0        1.0            moderate
# 3      Entire home/apt           4.0        1.0            flexible
# 4      Entire home/apt           2.0        1.0            moderate
# ...                ...           ...        ...                 ...
# 74106     Private room           1.0        1.0            flexible
# 74107  Entire home/apt           4.0        2.0            moderate
# 74108  Entire home/apt           5.0        1.0            moderate
# 74109  Entire home/apt           2.0        1.0              strict
# 74110  Entire home/apt           4.0        1.0            moderate
#
#       cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0             True                f                 100.0       1.0   1.0
# ...

# %%
#but in the cleaning fee true is not replace with 1 and false is not replace with 0 so we will drop this col

# %%
df['cleaning_fee']=df['cleaning_fee'].astype(str)
df['cleaning_fee'] = df['cleaning_fee'].replace({"True": 1, "False": 0})

# %%
df
# Out:
#              room_type  accommodates  bathrooms cancellation_policy  \
# 0      Entire home/apt           3.0        1.0              strict
# 1      Entire home/apt           7.0        1.0              strict
# 2      Entire home/apt           5.0        1.0            moderate
# 3      Entire home/apt           4.0        1.0            flexible
# 4      Entire home/apt           2.0        1.0            moderate
# ...                ...           ...        ...                 ...
# 74106     Private room           1.0        1.0            flexible
# 74107  Entire home/apt           4.0        2.0            moderate
# 74108  Entire home/apt           5.0        1.0            moderate
# 74109  Entire home/apt           2.0        1.0              strict
# 74110  Entire home/apt           4.0        1.0            moderate
#
#       cleaning_fee instant_bookable  review_scores_rating  bedrooms  beds  \
# 0                1                f                 100.0       1.0   1.0
# ...

# %%
 df['instant_bookable']=df['instant_bookable'].astype(str)
df['instant_bookable'] = df['instant_bookable'].replace(to_replace=["t","f"],value=[1,0])
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_9856\3402208898.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['instant_bookable'] = df['instant_bookable'].replace(to_replace=["t","f"],value=[1,0])

# %%
df
# Out:
#              room_type  accommodates  bathrooms cancellation_policy  \
# 0      Entire home/apt           3.0        1.0              strict
# 1      Entire home/apt           7.0        1.0              strict
# 2      Entire home/apt           5.0        1.0            moderate
# 3      Entire home/apt           4.0        1.0            flexible
# 4      Entire home/apt           2.0        1.0            moderate
# ...                ...           ...        ...                 ...
# 74106     Private room           1.0        1.0            flexible
# 74107  Entire home/apt           4.0        2.0            moderate
# 74108  Entire home/apt           5.0        1.0            moderate
# 74109  Entire home/apt           2.0        1.0              strict
# 74110  Entire home/apt           4.0        1.0            moderate
#
#       cleaning_fee  instant_bookable  review_scores_rating  bedrooms  beds  \
# ...

# %%
 df['cancellation_policy']=df['cancellation_policy'].astype(str)
df['cancellation_policy'] = df['cancellation_policy'].replace(to_replace=["strict","moderate","flexible"],value=[0,1,2])

# %%
df
# Out:
#              room_type  accommodates  bathrooms cancellation_policy  \
# 0      Entire home/apt           3.0        1.0                   0
# 1      Entire home/apt           7.0        1.0                   0
# 2      Entire home/apt           5.0        1.0                   1
# 3      Entire home/apt           4.0        1.0                   2
# 4      Entire home/apt           2.0        1.0                   1
# ...                ...           ...        ...                 ...
# 74106     Private room           1.0        1.0                   2
# 74107  Entire home/apt           4.0        2.0                   1
# 74108  Entire home/apt           5.0        1.0                   1
# 74109  Entire home/apt           2.0        1.0                   0
# 74110  Entire home/apt           4.0        1.0                   1
#
#       cleaning_fee  instant_bookable  review_scores_rating  bedrooms  beds  \
# ...

# %%
df['room_type']=df['room_type'].astype(str)
df['room_type'] = df['room_type'].replace(to_replace=["Entire home/apt","Private room","Shared room"],value=[1,2,3])

# %%
df
# Out:
#       room_type  accommodates  bathrooms cancellation_policy cleaning_fee  \
# 0             1           3.0        1.0                   0            1
# 1             1           7.0        1.0                   0            1
# 2             1           5.0        1.0                   1            1
# 3             1           4.0        1.0                   2            1
# 4             1           2.0        1.0                   1            1
# ...         ...           ...        ...                 ...          ...
# 74106         2           1.0        1.0                   2            0
# 74107         1           4.0        2.0                   1            1
# 74108         1           5.0        1.0                   1            1
# 74109         1           2.0        1.0                   0            1
# 74110         1           4.0        1.0                   1            0
#
#        instant_bookable  review_scores_rating  bedrooms  beds  log_price
# ...

# %%
# Now all the categorical values converted into integer
df[cat]
# Out:
#       room_type cancellation_policy cleaning_fee  instant_bookable
# 0             1                   0            1                 0
# 1             1                   0            1                 1
# 2             1                   1            1                 1
# 3             1                   2            1                 0
# 4             1                   1            1                 1
# ...         ...                 ...          ...               ...
# 74106         2                   2            0                 0
# 74107         1                   1            1                 0
# 74108         1                   1            1                 1
# 74109         1                   0            1                 1
# 74110         1                   1            0                 0
#
# [74111 rows x 4 columns]

# %% [markdown]
# # NULL VALUES TREATMENT

# %%
df.isnull().sum()
# Out:
# room_type                   0
# accommodates                3
# bathrooms                 203
# cancellation_policy         0
# cleaning_fee                0
# instant_bookable            0
# review_scores_rating    16722
# bedrooms                   92
# beds                      131
# log_price                   0
# dtype: int64

# %%
from sklearn.impute import KNNImputer

# %%
imputer = KNNImputer(n_neighbors=5)
imputed_df=imputer.fit_transform(df)

# %%
imputed_df
# Out:
# array([[1.        , 3.        , 1.        , ..., 1.        , 1.        ,
#         5.01063529],
#        [1.        , 7.        , 1.        , ..., 3.        , 3.        ,
#         5.12989872],
#        [1.        , 5.        , 1.        , ..., 1.        , 3.        ,
#         4.97673374],
#        ...,
#        [1.        , 5.        , 1.        , ..., 2.        , 2.        ,
#         5.22035583],
#        [1.        , 2.        , 1.        , ..., 0.        , 2.        ,
#         5.27299956],
#        [1.        , 4.        , 1.        , ..., 1.        , 2.        ,
#         4.85203026]])

# %%
# now what it will did it will convert all column into array

# %%
df=pd.DataFrame(imputed_df,columns=df.columns)

# %%
df
# Out:
#        room_type  accommodates  bathrooms  cancellation_policy  cleaning_fee  \
# 0            1.0           3.0        1.0                  0.0           1.0
# 1            1.0           7.0        1.0                  0.0           1.0
# 2            1.0           5.0        1.0                  1.0           1.0
# 3            1.0           4.0        1.0                  2.0           1.0
# 4            1.0           2.0        1.0                  1.0           1.0
# ...          ...           ...        ...                  ...           ...
# 74106        2.0           1.0        1.0                  2.0           0.0
# 74107        1.0           4.0        2.0                  1.0           1.0
# 74108        1.0           5.0        1.0                  1.0           1.0
# 74109        1.0           2.0        1.0                  0.0           1.0
# 74110        1.0           4.0        1.0                  1.0           0.0
#
# ...

# %%
df.isnull().sum()
# Out:
# room_type               0
# accommodates            0
# bathrooms               0
# cancellation_policy     0
# cleaning_fee            0
# instant_bookable        0
# review_scores_rating    0
# bedrooms                0
# beds                    0
# log_price               0
# dtype: int64

# %% [markdown]
# # Model Building

# %%
# STEPS
# 1.First we segregate the independent variables and dependent variables
# First we draw the vertical line manually by segregating the x and y
X = df.drop('log_price',axis=1)
Y= df['log_price']

# %%
# This all are independent variables
X
# Out:
#        room_type  accommodates  bathrooms  cancellation_policy  cleaning_fee  \
# 0            1.0           3.0        1.0                  0.0           1.0
# 1            1.0           7.0        1.0                  0.0           1.0
# 2            1.0           5.0        1.0                  1.0           1.0
# 3            1.0           4.0        1.0                  2.0           1.0
# 4            1.0           2.0        1.0                  1.0           1.0
# ...          ...           ...        ...                  ...           ...
# 74106        2.0           1.0        1.0                  2.0           0.0
# 74107        1.0           4.0        2.0                  1.0           1.0
# 74108        1.0           5.0        1.0                  1.0           1.0
# 74109        1.0           2.0        1.0                  0.0           1.0
# 74110        1.0           4.0        1.0                  1.0           0.0
#
# ...

# %%
# This is dependent variables
Y
# Out:
# 0        5.010635
# 1        5.129899
# 2        4.976734
# 3        6.620073
# 4        4.744932
#            ...
# 74106    4.605170
# 74107    5.043425
# 74108    5.220356
# 74109    5.273000
# 74110    4.852030
# Name: log_price, Length: 74111, dtype: float64

# %%
# 2.CREATE THE HORIZONTAL LINE FOR TEST TRAIN SPLIT CREATE THE 4 DATASETS X TRAIN X TEST Y TRAIN Y TEST

# %%
from sklearn.model_selection import train_test_split

# %%
# this function will draw the horizontal line
# test size is 30% remain is 70%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
X_train.head()
# Out:
#        room_type  accommodates  bathrooms  cancellation_policy  cleaning_fee  \
# 64132        2.0           1.0        2.0                  0.0           0.0
# 54279        2.0           2.0        1.0                  1.0           1.0
# 874          1.0           2.0        1.0                  2.0           1.0
# 9289         2.0           2.0        1.0                  2.0           0.0
# 26240        1.0           5.0        1.0                  0.0           1.0
#
#        instant_bookable  review_scores_rating  bedrooms  beds
# 64132               0.0                 100.0       1.0   1.0
# 54279               0.0                  96.0       1.0   1.0
# 874                 0.0                 100.0       1.0   1.0
# 9289                0.0                  70.0       1.0   2.0
# 26240               0.0                  77.8       0.0   3.0

# %%
X_train.shape
# Out:
# (51877, 9)

# %%
X_test.shape
# Out:
# (22234, 9)

# %%
Y_train.shape
# Out:
# (51877,)

# %%
Y_test.shape
# Out:
# (22234,)

# %%
LiR_model=LinearRegression()

# %%
LiR_model
# Out:
# LinearRegression()

# %%
LiR_model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# coefficient means m so here there are 9 columns so there are 9 coefficients
LiR_model.coef_
# Out:
# array([-6.11135614e-01,  8.04570013e-02,  1.51030469e-01,  3.69340188e-04,
#        -8.06023240e-02, -5.18854966e-02,  7.16389585e-03,  1.46947052e-01,
#        -4.60600500e-02])

# %%
# intercept is the c in equation
LiR_model.intercept_
# Out:
# np.float64(4.531199692901343)

# %%
for idx,col in enumerate(X_train.columns):
    print(f"The coefficient of {col} is {LiR_model.coef_[idx]}")
# Out:
# The coefficient of room_type is -0.6111356137227106
# The coefficient of accommodates is 0.08045700131994417
# The coefficient of bathrooms is 0.15103046924589758
# The coefficient of cancellation_policy is 0.00036934018819270026
# The coefficient of cleaning_fee is -0.0806023240042035
# The coefficient of instant_bookable is -0.05188549664237096
# The coefficient of review_scores_rating is 0.007163895845578142
# The coefficient of bedrooms is 0.14694705154300516
# The coefficient of beds is -0.04606004995142851

# %% [markdown]
# # MODEL EVALUATION

# %%
# Score means the relation between x and y
LiR_model.score(X_train,Y_train)
# Out:
# 0.5179472635613415

# %%
LiR_model.score(X_test,Y_test)
# Out:
# 0.5154430420783525

# %%
# here we got only the 51% of accuracy now we states that not much independent variable is available
# the score means 50 % of change in y using x.

# %% [markdown]
# ### Retrain the model by deleting the column to increase the accuracy

# %%
df_copy=df.copy()

# %%
df_copy.drop('beds',axis=1,inplace=True)

# %%
df_copy
# Out:
#        room_type  accommodates  bathrooms  cancellation_policy  cleaning_fee  \
# 0            1.0           3.0        1.0                  0.0           1.0
# 1            1.0           7.0        1.0                  0.0           1.0
# 2            1.0           5.0        1.0                  1.0           1.0
# 3            1.0           4.0        1.0                  2.0           1.0
# 4            1.0           2.0        1.0                  1.0           1.0
# ...          ...           ...        ...                  ...           ...
# 74106        2.0           1.0        1.0                  2.0           0.0
# 74107        1.0           4.0        2.0                  1.0           1.0
# 74108        1.0           5.0        1.0                  1.0           1.0
# 74109        1.0           2.0        1.0                  0.0           1.0
# 74110        1.0           4.0        1.0                  1.0           0.0
#
# ...

# %%
df
# Out:
#        room_type  accommodates  bathrooms  cancellation_policy  cleaning_fee  \
# 0            1.0           3.0        1.0                  0.0           1.0
# 1            1.0           7.0        1.0                  0.0           1.0
# 2            1.0           5.0        1.0                  1.0           1.0
# 3            1.0           4.0        1.0                  2.0           1.0
# 4            1.0           2.0        1.0                  1.0           1.0
# ...          ...           ...        ...                  ...           ...
# 74106        2.0           1.0        1.0                  2.0           0.0
# 74107        1.0           4.0        2.0                  1.0           1.0
# 74108        1.0           5.0        1.0                  1.0           1.0
# 74109        1.0           2.0        1.0                  0.0           1.0
# 74110        1.0           4.0        1.0                  1.0           0.0
#
# ...

# %%
Xc = df_copy.drop('log_price',axis=1)
Yc= df_copy['log_price']

Xc_train,Xc_test,Yc_train,Yc_test=train_test_split(Xc,Yc,test_size=0.3,random_state=1)

LiR_model.fit(Xc_train,Yc_train)

print(LiR_model.score(Xc_train,Yc_train))
print(LiR_model.score(Xc_test,Yc_test))
# Out:
# 0.5160105689388972
# 0.5124539458763575

# %%
# it will reduce the score by deleting the bed column it means the information loss if we delete the column so it is not preferred
# suppose now we consider that the score is 80% so now we will predict that

# %%
# refit the linear regression model into X and Y data

LiR_model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_train_predict = LiR_model.predict(X_train)
y_train_predict
# Out:
# array([4.50872299, 4.32926096, 4.96942149, ..., 5.59316802, 5.45552291,
#        5.29304897])

# %%
y_test_predict = LiR_model.predict(X_test)
y_test_predict
# Out:
# array([5.49651356, 4.35612467, 4.88680328, ..., 5.19543959, 4.25625311,
#        4.87555217])

# %% [markdown]
# ### MODEL REGULARIZATION (means make it better model from the previous one)

# %% [markdown]
# ### 1. Ridge
# ### 2. Lasso

# %% [markdown]
# ##### 1. Ridge

# %%
# if the coefficient is more equation is more violent so make coefficient as smaller as possible.

# %%
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso

# %%
from sklearn.metrics import r2_score

# %%
print(f"The regression model TRAIN SCORE is {LiR_model.score(X_train,Y_train)}")
print(f"The regression model TEST SCORE  is {LiR_model.score(X_test,Y_test)}")
# Out:
# 0.5179472635613415

# %%
ridge=Ridge(alpha=0.3)
ridge.fit(X_train,Y_train)
# Out:
# Ridge(alpha=0.3)

# %%
print(f"The regression model TRAIN SCORE is {ridge.score(X_train,Y_train)}")
print(f"The regression model TEST SCORE  is {ridge.score(X_test,Y_test)}")
# Out:
# The regression model TRAIN SCORE is 0.5179472634364028
# The regression model TEST SCORE  is 0.5154431788079261

# %%
ridge2=Ridge(alpha=0.8)
ridge2.fit(X_train,Y_train)
# Out:
# Ridge(alpha=0.8)

# %%
print(f"The regression model TRAIN SCORE is {ridge2.score(X_train,Y_train)}")
print(f"The regression model TEST SCORE  is {ridge2.score(X_test,Y_test)}")
# Out:
# The regression model TRAIN SCORE is 0.5179472626729724
# The regression model TEST SCORE  is 0.5154434061085948

# %%
ridge3=Ridge(alpha=8)
ridge3.fit(X_train,Y_train)
# Out:
# Ridge(alpha=8)

# %%
print(f"The regression model TRAIN SCORE is {ridge3.score(X_train,Y_train)}")
print(f"The regression model TEST SCORE  is {ridge3.score(X_test,Y_test)}")
# Out:
# The regression model TRAIN SCORE is 0.5179471748449664
# The regression model TEST SCORE  is 0.5154465986991645

# %%
# even we increase the alpha the accuracy is not increasing it means the information from which we fine tune the model is not sufficient thats why accuracy will not increase.

# %% [markdown]
# ### Lasso

# %%
L1=Lasso(alpha=0.3)
L1.fit(X_train,Y_train)
# Out:
# Lasso(alpha=0.3)

# %%
print(f"The regression model TRAIN SCORE is {L1.score(X_train,Y_train)}")
print(f"The regression model TEST SCORE  is {L1.score(X_test,Y_test)}")
# Out:
# The regression model TRAIN SCORE is 0.2919061546024099
# The regression model TEST SCORE  is 0.2939141759763545

# %%
L1=Lasso(alpha=0.05)
L1.fit(X_train,Y_train)
# Out:
# Lasso(alpha=0.05)

# %%
print(f"The regression model TRAIN SCORE is {L1.score(X_train,Y_train)}")
print(f"The regression model TEST SCORE  is {L1.score(X_test,Y_test)}")
# Out:
# The regression model TRAIN SCORE is 0.4773786281644452
# The regression model TEST SCORE  is 0.4770716505194843

# %%
L2=Lasso(alpha=0.000005)
L2.fit(X_train,Y_train)
# Out:
# Lasso(alpha=5e-06)

# %%
print(f"The regression model TRAIN SCORE is {L2.score(X_train,Y_train)}")
print(f"The regression model TEST SCORE  is {L2.score(X_test,Y_test)}")
# Out:
# The regression model TRAIN SCORE is 0.5179472622882145
# The regression model TEST SCORE  is 0.5154427270666698

# %%
L3=Lasso(alpha=0.00000000000005)
L3.fit(X_train,Y_train)
# Out:
# Lasso(alpha=5e-14)

# %%
print(f"The regression model TRAIN SCORE is {L3.score(X_train,Y_train)}")
print(f"The regression model TEST SCORE  is {L3.score(X_test,Y_test)}")
# Out:
# The regression model TRAIN SCORE is 0.5179472635613416
# The regression model TEST SCORE  is 0.5154430420783498

# %%
# as we decrease the value of alpha in lasso it will increase the accuracy or score but at the end it will stuck at 51 so it means information or data is not sufficient.

# %% [markdown]
# # The model is not successful is bcz of 2 things
# 1.we havent build the model properly
#
# 2.The data itself is not good enough
# But here we tried ridge and lasso also to increase the accuracy but the accuracy will not increases so it means we need more data
#
# 75 to 80 percent accuracy is good.
#
# Note=If the linear regression model gives u the good accuracy then we dont need the lasso and ridge regression.

# %% [markdown]
# # Non-Linear Model

# %%
from sklearn.preprocessing import PolynomialFeatures
# This PolynomialFeatures is nothing but we are trying to form the non linear equation between the same things over.

# %%
poly=PolynomialFeatures(degree=2,interaction_only=True)

# %%
X_poly=poly.fit_transform(X)
# here we transform the values of X thats why we do the fit transform we need to segregate the values of X into multiple 
#columns thats why we did this

# %%
Xp_train,Xp_test,Yp_train,Yp_test=train_test_split(X_poly,Y,test_size=0.3,random_state=1)

# %%
Xp_train.shape
# here it will create 46 columns from 9 columns here it will segreate the values into multiple column
# Out:
# (51877, 46)

# %%
LiR_model.fit(Xp_train,Yp_train)
# Out:
# LinearRegression()

# %%
LiR_model.score(Xp_train,Yp_train)
# Out:
# 0.5363533559510056

# %%
print(f"The regression model TRAIN SCORE is {LiR_model.score(Xp_train,Yp_train)}")
print(f"The regression model TEST SCORE  is {LiR_model.score(Xp_test,Yp_test)}")
# here we see it will increasing the accuracy of the model.
# Out:
# The regression model TRAIN SCORE is 0.5363533559510056
# The regression model TEST SCORE  is 0.5324239340800747

# %%
LiR_model.coef_
# here it will give the coefficient of 45 columns means 45 x's
# Out:
# array([-5.04536108e-16, -3.91893421e-01, -2.32101713e-02,  2.77595551e-01,
#        -1.20588725e-02,  1.16243818e-01, -2.45991706e-02,  2.82184065e-03,
#         2.90251110e-01,  1.62635543e-01,  2.16128336e-02, -2.40494055e-01,
#         5.08536026e-02,  3.38156198e-02,  1.53452840e-04,  9.06960633e-04,
#        -9.26749441e-02, -1.76554606e-02, -8.39827985e-03,  1.08947113e-02,
#        -2.81383560e-02,  1.00274172e-02,  1.21322720e-03, -1.65856631e-03,
#        -8.02067769e-03,  1.20350308e-02,  1.74255377e-03,  6.03576271e-03,
#         2.80649421e-03, -3.59740416e-03,  6.58202448e-03, -5.77740708e-02,
#        -2.21330824e-03, -4.55096285e-04, -1.44345833e-02, -5.53299419e-03,
#        -2.11012638e-02, -1.20953909e-03,  7.27345356e-03, -5.48305857e-04,
#        -1.12910235e-04, -9.59986989e-03, -1.44956963e-02, -7.99382519e-04,
#        -1.31268609e-03,  3.85736465e-03])

# %%
R=Ridge(alpha=0.03)
R.fit(Xp_train,Yp_train)
print(f"The regression model TRAIN SCORE is {R.score(Xp_train,Yp_train)}")
print(f"The regression model TEST SCORE  is {R.score(Xp_test,Yp_test)}")
# Out:
# The regression model TRAIN SCORE is 0.5363533557995656
# The regression model TEST SCORE  is 0.532423814091815

# %%
L=Lasso(alpha=0.003)
L.fit(Xp_train,Yp_train)
print(f"The regression model TRAIN SCORE is {L.score(Xp_train,Yp_train)}")
print(f"The regression model TEST SCORE  is {L.score(Xp_test,Yp_test)}")
# Out:
# The regression model TRAIN SCORE is 0.5326500186689171
# The regression model TEST SCORE  is 0.5282104213689012

# %%
L=Lasso(alpha=0.0003)
L.fit(Xp_train,Yp_train)
print(f"The regression model TRAIN SCORE is {L.score(Xp_train,Yp_train)}")
print(f"The regression model TEST SCORE  is {L.score(Xp_test,Yp_test)}")
# Out:
# The regression model TRAIN SCORE is 0.5359565260876056
# The regression model TEST SCORE  is 0.5316513884286551
# C:\Users\HP\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.944e+03, tolerance: 2.672e+00
#   model = cd_fast.enet_coordinate_descent(

# %%
# so here we see that it will give less accuracy than ridge so here we did lots of things with us data to increase the accuracy but the accuracy will not increase much more so now we conclude that the data is not sufficient so we will go to the data engineer for more data.

# %%
# hyperparameter tuning comes into classification
